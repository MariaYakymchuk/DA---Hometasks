# %% [markdown]
# 1. З колоди у 52 карти випадково витягується одна карта. Яка ймовірність того, що це туз, якщо відомо, що ця карта — пікова?

# %% [markdown]
# A — подія, що витягнута карта є тузом.
#
# B — подія, що витягнута карта є піковою.
#
# A∩B — подія, що витягнута карта — піковий туз.
#
# Ймовірність 𝑃(𝐵):
# P(B) — ймовірність того, що витягнута карта є піковою. У колоді є 13 пікових карт, тому: P(B) = 13/52 = 1/4
#
# 𝑃(A∩𝐵) = 1/52  Ймовірність перетину подій, тобто ймовіність витягнути з колоди піковий туз є 1
#
# P(A/B) = P(A∩B) / P(B) = (1/52) / (1/4) = 1/13 = 0.077%
#
# Отже, ймовірність того, що витягнута карта — туз, якщо відомо, що вона пікова, майже 8%

# %% [markdown]
# 2. У групі з 30 студентів є 18 хлопців і 12 дівчат. Відомо, що 7 хлопців і 5 дівчат носять окуляри. Випадково обраний студент носить окуляри. Яка ймовірність того, що цей студент — дівчина?

# %% [markdown]
# 𝑃(A∩𝐵) = ймовірність того, що обраний студент дівчинка та носить окуляри = 5/30  (тому що тільки 5 дівчат всього носять окуляри)
# P(B) = ймовірність того, що обраний студент носить окуляри = 12/30
#
# P(A/B) = P(A∩B) / P(B) = (5/30) / (12/30) = 5/12 = 0.0416
#
# Отже, ймовірність того, що випадково обраний студент дівчина, яка носить окуляри, майже 42%

# %% [markdown]
# 3. У конверті знаходяться 10 лотерейних білетів, серед яких 3 виграшних. З конверта послідовно витягуються білети. Знайти ймовірності того, що:
#
#     а) 2-й витягнутий білет буде виграшним, якщо 1-й був виграшним;
#     б) 3-й буде виграшним, якщо попередні два білети були виграшними;
#     в) 4-й буде виграшним, якщо попередні білети були виграшними.

# %% [markdown]
# а) Оскільки відомо, що перший білет був виграшним, після його витягування в конверті залишилося 9 білетів, з яких 2 виграшні (адже один виграшний білет вже витягнули).
#
# Тепер ймовірність того, що другий витягнутий білет буде виграшним: 2/9 = 0.22 = 22%
#
# б) Оскільки відомо, що перші 2 білети були виграшними, після їх витягування в конверті залишилося 8 білетів, з яких 1 виграшні (адже два виграшних білети вже витягнули).
#
# Тепер ймовірність того, що другий витягнутий білет буде виграшним: 1/8 = 0.125 = 12.5%
#
# в) Оскільки відомо, що перші 3 білети були виграшними, після їх витягування в конверті залишилося 7 білетів, з яких 0 виграшні (адже 3 виграшних білети вже витягнули).
#
# Тепер ймовірність того, що другий витягнутий білет буде виграшним: 0/7 = 0
