# %% [markdown]
# 1.  У медичному центрі проводять тест на певну хворобу. Відомо, що 1% населення страждає на цю хворобу. Тест дає позитивний результат у 99% випадків для хворих і 5% випадків для здорових людей (хибнопозитивний результат). Якщо тест показав позитивний результат, яка ймовірність того, що людина насправді хвора?

# %% [markdown]
# P(H)=0.01 — ймовірність того, що людина хвора (1% населення).
#
# P(S)=0.99 — ймовірність того, що людина здорова (99% населення).
#
# P(+∣H)=0.99 — ймовірність позитивного тесту, якщо людина хвора (99%).
#
# P(+∣S)=0.05 — ймовірність позитивного тесту, якщо людина здорова (5%).
#
# P(H∣+) — ймовірність того, що людина хвора, якщо тест показав позитивний результат.
#
# P(H∣+) = (P(+∣H) * P(H)) / P(+)
#
# P(+) = P(+∣H) * P(H) + 𝑃(+∣𝑆) * P(S) = 0.99 * 0.01 + 0.05 * 0.99 = 0.0594
#
# P(H∣+) = (0.99 * 0.01) / 0.0584 = 0.1667
#
# Таким чином, ймовірність того, що людина хвора, якщо тест показав позитивний результат, становить приблизно 16.67%.

# %% [markdown]
# 2. У компанії 70% співробітників чесні, а 30% можуть інколи брехати. Детектор брехні правильно ідентифікує чесних співробітників у 90% випадків і неправильно класифікує їх як таких, що брехали, у 10% випадків. Якщо детектор показав, що співробітник брехав, яка ймовірність того, що він насправді брехав?

# %% [markdown]
# P(A)=0.7 — ймовірність того, що людина чесна
#
# P(A-)=0.3 — ймовірність того, що людина здорова бреше
#
# D — детектор показав, що співробітник брехав.
#
# P(D∣A-) — ймовірність того, що детектор покаже, що співробітник брехав, за умови, що він насправді брехав. За умовою задачі, ми припускаємо, що детектор правильно розпізнає брехунів = 1
#
# P(D∣A) — ймовірність того, що детектор покаже, що співробітник брехав, за умови, що він насправді чесний. Це ймовірність помилки детектора для чесних, яка дорівнює 10%, тобто = 0.1
#
# P(A-∣D) = (P(D∣A-) * P(A-)) / P(D)
#
# P(D) = P(D∣A-) * P(A-) + P(D∣A) * P(A) = 1 * 0.3 + 0.1 * 0.7 = 0.3 + 0.07 = 0.37
#
# P(A-∣D) = (1 * 0.3) / 0.37 = 0.81
#
# Якщо детектор показав, що співробітник брехав, ймовірність того, що він дійсно брехав, становить приблизно 81%.

# %% [markdown]
# 3. Відомо, що предмет можна загубити в одній з трьох кімнат: у першій кімнаті з ймовірністю 0,5, у другій — з ймовірністю 0,3, і в третій — з ймовірністю 0,2. Якщо предмет загублено в кімнаті, ймовірність знайти його під час пошуку складає 0,8 для першої кімнати, 0,6 для другої і 0,4 для третьої. Якщо предмет знайшли, яка ймовірність того, що його було загублено в першій кімнаті?

# %% [markdown]
# A1— подія, що предмет було загублено в першій кімнаті.
#
# A2— подія, що предмет було загублено в другій кімнаті.
#
# A3 — подія, що предмет було загублено в третій кімнаті.
#
# B — подія, що предмет знайшли.
#
# P(A1)=0.5
#
# P(A2)=0.3
#
# P(A3)=0.2
#
#
# P(B∣A1)=0.8 (ймовірність знайти предмет, якщо його загубили в першій кімнаті).
#
# P(B∣A2)=0.6 (ймовірність знайти предмет, якщо його загубили в другій кімнаті).
#
# P(B∣A3)=0.4 (ймовірність знайти предмет, якщо його загубили в третій кімнаті).
#
# P(A1∣B) — ймовірність того, що предмет було загублено в першій кімнаті, за умови, що його знайшли.
#
# P(A1∣B) = (P(B∣A1) * P(A1)) / P(B)
#
# P(B) = P(B∣A1)⋅P(A1)+P(B∣A2)⋅P(A2)+P(B∣A3)⋅P(A3)
#
# P(B)=(0.8⋅0.5)+(0.6⋅0.3)+(0.4⋅0.2)= 0.66
#
# P(A1∣B) = (0.8*0.5) / 0.66 = 0.60
#
# Отже, ймовірність того, що предмет було загублено в першій кімнаті, за умови, що його знайшли, становить приблизно 60.61%.

# %% [markdown]
# 4. На заводі виробляють продукцію на трьох лініях: 50% продукції випускає перша лінія, 30% — друга, і 20% — третя. Відомо, що 2% продукції з першої лінії, 3% з другої і 5% з третьої мають дефекти. Якщо випадково обрана продукція має дефект, яка ймовірність того, що вона була випущена третьою лінією?

# %% [markdown]
# A1 - ймовірність того, що продукція випущена на першій лінії - 0.5
#
# A2 - ймовірність того, що продукція випущена на другій лінії - 0.3
#
# A3 - ймовірність того, що продукція випущена на третій лінії - 0.2
#
# Р - виготовлена зіпсована продукція
#
# P(Р∣A1)=0.02 (ймовірність, що продукція зіпсована на першій лінії).
#
# P(Р∣A2)=0.03 (ймовірність, що продукція зіпсована на другій лінії).
#
# P(Р∣A3)=0.05 (ймовірність, що продукція зіпсована на третій лінії).
#
# P(A3∣Р) = (P(B∣A3) * P(A3)) / P(Р)
#
# P(Р) = P(Р∣A1)⋅P(A1)+P(Р∣A2)⋅P(A2)+P(Р∣A3)⋅P(A3) = 0.02*0.5 + 0.03*0.3 + 0.05*0.2 = 0.01 + 0.009 + 0.01 = 0.029
#
# P(A3∣Р) = ((0.05*0.2) * 0.2) / 0.029 = 0.3448
#
# Ймовірність того, що продукція з дефектом була випущена третьою лінією, становить приблизно 34.48%.

# %% [markdown]
# 5. Програма для розпізнавання рукописних цифр має точність 95% для цифри "3" і 98% для інших цифр. Якщо на вхід програми подано цифру "3", а програма її не розпізнала, яка ймовірність того, що насправді була подана цифра "3"? Відомо, що в 20% випадків на вхід подається цифра "3".

# %% [markdown]
# P(А) = 0.20  — ймовірність того, що подана цифра "3".
#
# P(А-) =  0.80  — ймовірність того, що подано не "3".
#
# В - подія, коли програма не змогла правильно розпізнати подану цифру
#
# P(В | А) = 0.05  — ймовірність того, що цифра "3" не буде розпізнана
#
# P(В | А-) =  0.02  — ймовірність того, що будь-яка інша цифра не буде розпізнана.
#
# P(А | В) = ( P(B | A) * P(A)) / P(B)
#
# P(B) = P(B | A) * P(A) + P(В | А-) * P(А-) = 0.05 * 0.2 + 0.02 * 0.80 = 0.01 + 0.016 = 0.026
#
# P(А | В) = (0.05 * 0.2) / 0.026 = 0.3846
#
# Отже, ймовірність того, що насправді була подана цифра "3", за умови, що програма її не розпізнала, приблизно дорівнює 38.46 %.
